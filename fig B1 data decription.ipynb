# %%
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter
import seaborn as sns

# %%
path1 = r'E:\netData\APS\1 Authors\APS_authors 2.0.zip'
path2 = r"E:\netData\APS\3 Paper\nodepro2010.zip"
path3 = r'E:\netData\APS\DCCC\paper DCCC2010.zip'

# %%
f1 = pd.read_csv(path1)
f2 = pd.read_csv(path2)
f3 = pd.read_csv(path3)

# %%
f1['type'] = f1['type'].map(dict(zip(['获奖学者','非获奖学者'] , ['laureate' , 'non laureate'])))

# %% [markdown]
# # draw

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10, 6))

g = sns.lineplot(
    data=f23,x="year", y=r'DC'
)

ax.yaxis.grid(True)

g.set_xticks([1910,1930,1950,1970,1990,2010])

plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel(r'disruptive citations (DC)',fontsize = 25)

ax.set(xlabel="")
sns.despine(trim=True, left=True)
plt.savefig(r"F:\目前研究项目\APS分析\IPM SDC SCC\fig\fig A1\fig1DC.pdf",bbox_inches = 'tight')

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10, 6))

g = sns.lineplot(
    data=f23,x="year", y=r'CC'
)

ax.yaxis.grid(True)

g.set_xticks([1910,1930,1950,1970,1990,2010])

plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel(r'consolidating citations (CC)',fontsize = 25)

ax.set(xlabel="")
sns.despine(trim=True, left=True)
plt.savefig(r"F:\目前研究项目\APS分析\IPM SDC SCC\fig\fig A1\fig1CC.pdf",bbox_inches = 'tight')

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10, 6))

g = sns.lineplot(
    data=f22,x="year", y=r'indegree'
)

ax.yaxis.grid(True)

g.set_xticks([1910,1930,1950,1970,1990,2010])

plt.xticks(size = 20)
plt.yticks(size = 20)
plt.ylabel(r'citations',fontsize = 25)

ax.set(xlabel="")
sns.despine(trim=True, left=True)
plt.savefig(r"F:\目前研究项目\APS分析\IPM SDC SCC\fig\fig A1\fig1TC.pdf",bbox_inches = 'tight')

# %%
f23['journals'] = f23['journal'].map(dict(zip(f22['journal'].unique() , ['Physical Review', 'Physical Review A', 'Physical Review B',
       'Physical Review C', 'Physical Review D', 'Physical Review E',
       'Physical Review', 'Physical Review Letters',
       'Physical Review',
       'Physical Review',
       'Reviews of Modern Physics'])))
f22['journals'] = f22['journal'].map(dict(zip(f22['journal'].unique() , ['Physical Review', 'Physical Review A', 'Physical Review B',
       'Physical Review C', 'Physical Review D', 'Physical Review E',
       'Physical Review', 'Physical Review Letters',
       'Physical Review',
       'Physical Review',
       'Reviews of Modern Physics'])))

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 7))
#ax.set_xscale("log")
# font
plt.rcParams["font.family"] = "Arial"
plt.rcParams["text.usetex"] = False


sns.barplot(
    data=f23,x=r'DC', y="journals"
)

ax.set_xscale("log")
ax.xaxis.grid(True)

plt.xticks([10e-1 , 10e0 , 10e1] , size = 20)
plt.yticks(size = 20)
plt.xlabel(r'disruptive citations (DC)',fontsize = 25)

ax.set(ylabel="")
sns.despine(trim=True, left=True)

plt.savefig(r"F:\目前研究项目\APS分析\IPM SDC SCC\fig\fig A1\DC J.pdf",bbox_inches = 'tight')

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 7))
#ax.set_xscale("log")
# font
plt.rcParams["font.family"] = "Arial"
plt.rcParams["text.usetex"] = False


sns.barplot(
    data=f23,x=r'CC', y="journals"
)

ax.set_xscale("log")
ax.xaxis.grid(True)

plt.xticks([10e-1 , 10e0 , 10e1] , size = 20)
plt.yticks(size = 20)
plt.xlabel(r'consolidating citations (CC)',fontsize = 25)

ax.set(ylabel="")
sns.despine(trim=True, left=True)

plt.savefig(r"F:\目前研究项目\APS分析\IPM SDC SCC\fig\fig A1\CC J.pdf",bbox_inches = 'tight')

# %%
sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 7))
#ax.set_xscale("log")
# font
plt.rcParams["font.family"] = "Arial"
plt.rcParams["text.usetex"] = False


sns.barplot(
    data=f22,x=r'indegree', y="journals"
)
ax.set_xscale("log")
ax.xaxis.grid(True)

plt.xticks([10e-1 , 10e0 , 10e1] , size = 20)
plt.yticks(size = 20)
plt.xlabel(r'citations',fontsize = 25)

ax.set(ylabel="")
sns.despine(trim=True, left=True)

plt.savefig(r"F:\目前研究项目\APS分析\IPM SDC SCC\fig\fig A1\TC J.pdf",bbox_inches = 'tight')
